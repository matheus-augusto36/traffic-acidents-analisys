# %%
import pandas as pd

# %%
df_sinistros = pd.read_excel('Formato Novo/sinistros_2022-2025.xlsx')

# %%
pd.set_option('display.max_columns', None)

# %%
df_sinistros
# Out:
#           id_sinistro       tipo_registro data_sinistro hora_sinistro  \
# 8             1557410  Sinistro Não Fatal    2022-01-04      20:09:00
# 12            2072299  Sinistro Não Fatal    2022-01-04      12:15:00
# 17            1365234  Sinistro Não Fatal    2022-01-05      17:10:00
# 20            1678076  Sinistro Não Fatal    2022-01-05      22:28:00
# 21            1824438  Sinistro Não Fatal    2022-01-05      06:52:00
# ...               ...                 ...           ...           ...
# 13794016      2605204  Sinistro Não Fatal    2025-05-20      08:13:00
# 13794189      2604901  Sinistro Não Fatal    2025-05-28      07:32:00
# 13794191      2607605  Sinistro Não Fatal    2025-05-28      11:01:00
# 13794203      2607530  Sinistro Não Fatal    2025-05-29      07:10:00
# 13794204      2606142  Sinistro Não Fatal    2025-05-29      09:16:00
#
#                               logradouro  numero_logradouro         tipo_via  \
# 8                     Praça Dos Andradas                1.0  Vias Municipais
# 12                     Estrada Do Elenco              915.0  Vias Municipais
# 17                    Rua Júlio Mesquita              206.0  Vias Municipais
# 20              Acesso Manoel Da Nóbrega                1.0  Vias Municipais
# 21                                Sp 055              324.0         Rodovias
# ...                                  ...                ...              ...
# 13794016  Rua Joaquina Angelica Ferreira              265.0  Vias Municipais
# 13794189         Avenida Paschoal Thomeu              100.0  Vias Municipais
# 13794191                      Rua Brasil             1401.0  Vias Municipais
# 13794203                     Rua Angical                1.0  Vias Municipais
# 13794204            Avenida Capitao Joao              100.0  Vias Municipais
#
#            latitude  longitude            municipio  \
# 8        -23.936463 -46.332609               Santos
# 12       -23.411059 -46.485206            Guarulhos
# 17       -23.522161 -47.474900             Sorocaba
# 20       -23.993034 -46.495588          Sao Vicente
# 21       -24.151463 -46.732772             Itanhaem
# ...             ...        ...                  ...
# 13794016 -20.045300 -47.747840            Igarapava
# 13794189 -23.423120 -46.407210            Guarulhos
# 13794191 -23.209896 -46.873071              Jundiai
# 13794203 -23.254958 -45.909890  Sao Jose Dos Campos
# 13794204 -23.668581 -46.462012                 Maua
#
#                regiao_administrativa administracao   conservacao jurisdicao  \
# 8                   Baixada Santista    Prefeitura    Prefeitura  Municipal
# 12        Metropolitana de São Paulo    Prefeitura    Prefeitura  Municipal
# 17                          Sorocaba    Prefeitura    Prefeitura  Municipal
# 20                  Baixada Santista    Prefeitura    Prefeitura  Municipal
# 21                  Baixada Santista        ARTESP  Novo Litoral   Estadual
# ...                              ...           ...           ...        ...
# 13794016                      Franca    Prefeitura    Prefeitura  Municipal
# 13794189  Metropolitana de São Paulo    Prefeitura    Prefeitura  Municipal
# 13794191                    Campinas    Prefeitura    Prefeitura  Municipal
# 13794203         São José dos Campos    Prefeitura    Prefeitura  Municipal
# 13794204  Metropolitana de São Paulo    Prefeitura    Prefeitura  Municipal
#
#          tipo_acidente_primario tipo_de_veiculo gravidade  tipo_sinistro
# 8                 ATROPELAMENTO       Bicicleta      None  Atropelamento
# 12                ATROPELAMENTO       Bicicleta      None  Atropelamento
# 17                ATROPELAMENTO       Bicicleta      None  Atropelamento
# 20                ATROPELAMENTO       Bicicleta      None  Atropelamento
# 21                ATROPELAMENTO       Bicicleta      None  Atropelamento
# ...                         ...             ...       ...            ...
# 13794016         NAO DISPONIVEL       Automóvel     Grave           None
# 13794189         NAO DISPONIVEL       Automóvel     Grave           None
# 13794191                COLISAO       Automóvel     Grave        Colisão
# 13794203         NAO DISPONIVEL       Automóvel     Grave           None
# 13794204          ATROPELAMENTO       Automóvel     Grave  Atropelamento
#
# [1772552 rows x 18 columns]

# %%
df_sinistros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672524 entries, 0 to 672523
# Data columns (total 43 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   id_sinistro                      672524 non-null  int64
#  1   tipo_registro                    672524 non-null  object
#  2   data_sinistro                    672524 non-null  datetime64[ns]
#  3   ano_sinistro                     672524 non-null  int64
#  4   mes_sinistro                     672524 non-null  int64
#  5   dia_sinistro                     672524 non-null  int64
#  6   ano_mes_sinistro                 672524 non-null  object
#  7   hora_sinistro                    671757 non-null  object
#  8   logradouro                       671005 non-null  object
#  9   numero_logradouro                670258 non-null  float64
#  10  tipo_via                         672524 non-null  object
#  11  latitude                         669873 non-null  float64
#  12  longitude                        669874 non-null  float64
#  13  municipio                        672518 non-null  object
#  14  regiao_administrativa            672518 non-null  object
#  15  tp_veiculo_bicicleta             15784 non-null   float64
#  16  tp_veiculo_caminhao              24763 non-null   float64
#  17  tp_veiculo_motocicleta           258190 non-null  float64
#  18  tp_veiculo_nao_disponivel        78912 non-null   float64
#  19  tp_veiculo_onibus                16163 non-null   float64
#  20  tp_veiculo_outros                17418 non-null   float64
#  21  tp_veiculo_automovel             269029 non-null  float64
#  22  gravidade_nao_disponivel         327275 non-null  float64
#  23  gravidade_leve                   327878 non-null  float64
#  24  gravidade_fatal                  18362 non-null   float64
#  25  gravidade_ileso                  0 non-null       float64
#  26  gravidade_grave                  41626 non-null   float64
#  27  administracao                    670506 non-null  object
#  28  conservacao                      670506 non-null  object
#  29  jurisdicao                       670506 non-null  object
#  30  tipo_acidente_primario           672524 non-null  object
#  31  tp_sinistro_atropelamento        60582 non-null   object
#  32  tp_sinistro_colisao_frontal      87965 non-null   object
#  33  tp_sinistro_colisao_traseira     64276 non-null   object
#  34  tp_sinistro_colisao_lateral      139702 non-null  object
#  35  tp_sinistro_colisao_transversal  19032 non-null   object
#  36  tp_sinistro_colisao_outros       1466 non-null    object
#  37  tp_sinistro_choque               46623 non-null   object
#  38  tp_sinistro_capotamento          13807 non-null   object
#  39  tp_sinistro_engavetamento        4014 non-null    object
#  40  tp_sinistro_tombamento           41626 non-null   object
#  41  tp_sinistro_outros               306653 non-null  object
#  42  tp_sinistro_nao_disponivel       118057 non-null  object
# dtypes: datetime64[ns](1), float64(15), int64(4), object(23)
# memory usage: 220.6+ MB

# %%
df_sinistros.tipo_registro.value_counts()
# Out:
# tipo_registro
# SINISTRO NAO FATAL    433884
# NOTIFICACAO           220278
# SINISTRO FATAL         18362
# Name: count, dtype: int64

# %%
df_sinistros = df_sinistros[df_sinistros['tipo_registro'] != "NOTIFICACAO"]

# %%
df_sinistros[['tp_sinistro_atropelamento', 'tp_sinistro_colisao_frontal', 'tp_sinistro_colisao_traseira',
    'tp_sinistro_colisao_lateral', 'tp_sinistro_colisao_transversal', 'tp_sinistro_colisao_outros']]
# Out:
#        tp_sinistro_atropelamento tp_sinistro_colisao_frontal  \
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
# 5                            NaN                         NaN
# 6                            NaN                         NaN
# ...                          ...                         ...
# 672508                       NaN                         NaN
# 672512                       NaN                         NaN
# 672513                       NaN                         NaN
# 672515                       NaN                         NaN
# 672519                       NaN                         NaN
#
#        tp_sinistro_colisao_traseira tp_sinistro_colisao_lateral  \
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                               NaN                         NaN
# 5                               NaN                         NaN
# 6                               NaN                         NaN
# ...                             ...                         ...
# 672508                            S                         NaN
# 672512                            S                         NaN
# 672513                          NaN                         NaN
# 672515                            S                         NaN
# 672519                          NaN                         NaN
#
#        tp_sinistro_colisao_transversal tp_sinistro_colisao_outros
# 2                                  NaN                          S
# 3                                  NaN                        NaN
# 4                                  NaN                        NaN
# 5                                  NaN                        NaN
# 6                                  NaN                        NaN
# ...                                ...                        ...
# 672508                             NaN                        NaN
# 672512                             NaN                        NaN
# 672513                             NaN                        NaN
# 672515                             NaN                        NaN
# 672519                             NaN                        NaN
#
# [452246 rows x 6 columns]

# %%
colunas_veiculo = [
    'tp_veiculo_bicicleta', 'tp_veiculo_caminhao', 'tp_veiculo_motocicleta',
    'tp_veiculo_nao_disponivel', 'tp_veiculo_onibus', 'tp_veiculo_outros',
    'tp_veiculo_automovel'
]


df_sinistros = df_sinistros.melt(
    id_vars=[col for col in df_sinistros.columns if col not in colunas_veiculo],  
    value_vars=colunas_veiculo,
    var_name='tipo_de_veiculo',
    value_name='valor'
)

# %%
df_sinistros = df_sinistros.dropna(subset=['valor']).drop(columns='valor')

# %%
df_sinistros['tipo_de_veiculo'] = df_sinistros['tipo_de_veiculo'].str.replace('tp_veiculo_', '')

# %%
df_sinistros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 678863 entries, 236 to 3165721
# Data columns (total 37 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   id_sinistro                      678863 non-null  int64
#  1   tipo_registro                    678863 non-null  object
#  2   data_sinistro                    678863 non-null  datetime64[ns]
#  3   ano_sinistro                     678863 non-null  int64
#  4   mes_sinistro                     678863 non-null  int64
#  5   dia_sinistro                     678863 non-null  int64
#  6   ano_mes_sinistro                 678863 non-null  object
#  7   hora_sinistro                    677988 non-null  object
#  8   logradouro                       677293 non-null  object
#  9   numero_logradouro                676289 non-null  float64
#  10  tipo_via                         678863 non-null  object
#  11  latitude                         675985 non-null  float64
#  12  longitude                        675986 non-null  float64
#  13  municipio                        678858 non-null  object
#  14  regiao_administrativa            678858 non-null  object
#  15  gravidade_nao_disponivel         539094 non-null  float64
#  16  gravidade_leve                   520577 non-null  float64
#  17  gravidade_fatal                  24481 non-null   float64
#  18  gravidade_ileso                  0 non-null       float64
#  19  gravidade_grave                  65369 non-null   float64
#  20  administracao                    678602 non-null  object
#  21  conservacao                      678602 non-null  object
#  22  jurisdicao                       678602 non-null  object
#  23  tipo_acidente_primario           678863 non-null  object
#  24  tp_sinistro_atropelamento        46467 non-null   object
#  25  tp_sinistro_colisao_frontal      146509 non-null  object
#  26  tp_sinistro_colisao_traseira     110499 non-null  object
#  27  tp_sinistro_colisao_lateral      248626 non-null  object
#  28  tp_sinistro_colisao_transversal  32640 non-null   object
#  29  tp_sinistro_colisao_outros       2194 non-null    object
#  30  tp_sinistro_choque               60107 non-null   object
#  31  tp_sinistro_capotamento          14911 non-null   object
#  32  tp_sinistro_engavetamento        6244 non-null    object
#  33  tp_sinistro_tombamento           57790 non-null   object
#  34  tp_sinistro_outros               258985 non-null  object
#  35  tp_sinistro_nao_disponivel       43824 non-null   object
#  36  tipo_de_veiculo                  678863 non-null  object
# dtypes: datetime64[ns](1), float64(8), int64(4), object(24)
# memory usage: 196.8+ MB

# %%
colunas_gravidade = [
    'gravidade_nao_disponivel', 'gravidade_leve', 'gravidade_fatal',
    'gravidade_ileso', 'gravidade_grave'
]


df_sinistros = df_sinistros.melt(
    id_vars=[col for col in df_sinistros.columns if col not in colunas_gravidade],  
    value_vars=colunas_gravidade,
    var_name='gravidade',
    value_name='valor'
)

# %%
df_sinistros = df_sinistros.dropna(subset=['valor']).drop(columns='valor')

# %%
df_sinistros['gravidade'] = df_sinistros['gravidade'].str.replace('gravidade_', '')

# %%
df_sinistros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1149521 entries, 0 to 3394309
# Data columns (total 33 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   id_sinistro                      1149521 non-null  int64
#  1   tipo_registro                    1149521 non-null  object
#  2   data_sinistro                    1149521 non-null  datetime64[ns]
#  3   ano_sinistro                     1149521 non-null  int64
#  4   mes_sinistro                     1149521 non-null  int64
#  5   dia_sinistro                     1149521 non-null  int64
#  6   ano_mes_sinistro                 1149521 non-null  object
#  7   hora_sinistro                    1148515 non-null  object
#  8   logradouro                       1147602 non-null  object
#  9   numero_logradouro                1146649 non-null  float64
#  10  tipo_via                         1149521 non-null  object
#  11  latitude                         1146181 non-null  float64
#  12  longitude                        1146182 non-null  float64
#  13  municipio                        1149516 non-null  object
#  14  regiao_administrativa            1149516 non-null  object
#  15  administracao                    1149054 non-null  object
#  16  conservacao                      1149054 non-null  object
#  17  jurisdicao                       1149054 non-null  object
#  18  tipo_acidente_primario           1149521 non-null  object
#  19  tp_sinistro_atropelamento        77236 non-null    object
#  20  tp_sinistro_colisao_frontal      269489 non-null   object
#  21  tp_sinistro_colisao_traseira     199617 non-null   object
#  22  tp_sinistro_colisao_lateral      461461 non-null   object
#  23  tp_sinistro_colisao_transversal  60145 non-null    object
#  24  tp_sinistro_colisao_outros       2835 non-null     object
#  25  tp_sinistro_choque               93723 non-null    object
#  26  tp_sinistro_capotamento          20980 non-null    object
#  27  tp_sinistro_engavetamento        11145 non-null    object
#  28  tp_sinistro_tombamento           89923 non-null    object
#  29  tp_sinistro_outros               429412 non-null   object
#  30  tp_sinistro_nao_disponivel       56586 non-null    object
#  31  tipo_de_veiculo                  1149521 non-null  object
#  32  gravidade                        1149521 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(4), object(25)
# memory usage: 298.2+ MB

# %%
colunas_colisao = [
    'tp_sinistro_atropelamento', 'tp_sinistro_colisao_frontal', 'tp_sinistro_colisao_traseira',
    'tp_sinistro_colisao_lateral', 'tp_sinistro_colisao_transversal', 'tp_sinistro_colisao_outros',
    'tp_sinistro_choque', 'tp_sinistro_capotamento', 'tp_sinistro_engavetamento', 'tp_sinistro_tombamento', 'tp_sinistro_outros',
    'tp_sinistro_nao_disponivel' 
]


df_sinistros = df_sinistros.melt(
    id_vars=[col for col in df_sinistros.columns if col not in colunas_colisao],  
    value_vars=colunas_colisao,
    var_name='tipo_sinistro',
    value_name='valor'
)

# %%
df_sinistros = df_sinistros.dropna(subset=['valor']).drop(columns='valor')

# %%
df_sinistros['tipo_sinistro'] = df_sinistros['tipo_sinistro'].str.replace('tp_sinistro_', '')

# %%
df_sinistros
# Out:
#           id_sinistro       tipo_registro data_sinistro  ano_sinistro  \
# 8             1557410  SINISTRO NAO FATAL    2022-01-04          2022
# 12            2072299  SINISTRO NAO FATAL    2022-01-04          2022
# 17            1365234  SINISTRO NAO FATAL    2022-01-05          2022
# 20            1678076  SINISTRO NAO FATAL    2022-01-05          2022
# 21            1824438  SINISTRO NAO FATAL    2022-01-05          2022
# ...               ...                 ...           ...           ...
# 13794016      2605204  SINISTRO NAO FATAL    2025-05-20          2025
# 13794189      2604901  SINISTRO NAO FATAL    2025-05-28          2025
# 13794191      2607605  SINISTRO NAO FATAL    2025-05-28          2025
# 13794203      2607530  SINISTRO NAO FATAL    2025-05-29          2025
# 13794204      2606142  SINISTRO NAO FATAL    2025-05-29          2025
#
#           mes_sinistro  dia_sinistro ano_mes_sinistro hora_sinistro  \
# 8                    1             4          2022/01      20:09:00
# 12                   1             4          2022/01      12:15:00
# 17                   1             5          2022/01      17:10:00
# 20                   1             5          2022/01      22:28:00
# 21                   1             5          2022/01      06:52:00
# ...                ...           ...              ...           ...
# 13794016             5            20          2025/05      08:13:00
# 13794189             5            28          2025/05      07:32:00
# 13794191             5            28          2025/05      11:01:00
# 13794203             5            29          2025/05      07:10:00
# 13794204             5            29          2025/05      09:16:00
#
#                               logradouro  numero_logradouro         tipo_via  \
# 8                     PRAÇA DOS ANDRADAS                1.0  VIAS MUNICIPAIS
# 12                     ESTRADA DO ELENCO              915.0  VIAS MUNICIPAIS
# 17                    RUA JÚLIO MESQUITA              206.0  VIAS MUNICIPAIS
# 20              ACESSO MANOEL DA NÓBREGA                1.0  VIAS MUNICIPAIS
# 21                                SP 055              324.0         RODOVIAS
# ...                                  ...                ...              ...
# 13794016  RUA JOAQUINA ANGELICA FERREIRA              265.0  VIAS MUNICIPAIS
# 13794189         AVENIDA PASCHOAL THOMEU              100.0  VIAS MUNICIPAIS
# 13794191                      RUA BRASIL             1401.0  VIAS MUNICIPAIS
# 13794203                     RUA ANGICAL                1.0  VIAS MUNICIPAIS
# 13794204            AVENIDA CAPITAO JOAO              100.0  VIAS MUNICIPAIS
#
#            latitude  longitude            municipio  \
# 8        -23.936463 -46.332609               SANTOS
# 12       -23.411059 -46.485206            GUARULHOS
# 17       -23.522161 -47.474900             SOROCABA
# 20       -23.993034 -46.495588          SAO VICENTE
# 21       -24.151463 -46.732772             ITANHAEM
# ...             ...        ...                  ...
# 13794016 -20.045300 -47.747840            IGARAPAVA
# 13794189 -23.423120 -46.407210            GUARULHOS
# 13794191 -23.209896 -46.873071              JUNDIAI
# 13794203 -23.254958 -45.909890  SAO JOSE DOS CAMPOS
# 13794204 -23.668581 -46.462012                 MAUA
#
#                regiao_administrativa administracao   conservacao jurisdicao  \
# 8                   Baixada Santista    PREFEITURA    PREFEITURA  MUNICIPAL
# 12        Metropolitana de São Paulo    PREFEITURA    PREFEITURA  MUNICIPAL
# 17                          Sorocaba    PREFEITURA    PREFEITURA  MUNICIPAL
# 20                  Baixada Santista    PREFEITURA    PREFEITURA  MUNICIPAL
# 21                  Baixada Santista        ARTESP  NOVO LITORAL   ESTADUAL
# ...                              ...           ...           ...        ...
# 13794016                      Franca    PREFEITURA    PREFEITURA  MUNICIPAL
# 13794189  Metropolitana de São Paulo    PREFEITURA    PREFEITURA  MUNICIPAL
# 13794191                    Campinas    PREFEITURA    PREFEITURA  MUNICIPAL
# 13794203         São José dos Campos    PREFEITURA    PREFEITURA  MUNICIPAL
# 13794204  Metropolitana de São Paulo    PREFEITURA    PREFEITURA  MUNICIPAL
#
#          tipo_acidente_primario tipo_de_veiculo       gravidade  \
# 8                 ATROPELAMENTO       bicicleta  nao_disponivel
# 12                ATROPELAMENTO       bicicleta  nao_disponivel
# 17                ATROPELAMENTO       bicicleta  nao_disponivel
# 20                ATROPELAMENTO       bicicleta  nao_disponivel
# 21                ATROPELAMENTO       bicicleta  nao_disponivel
# ...                         ...             ...             ...
# 13794016         NAO DISPONIVEL       automovel           grave
# 13794189         NAO DISPONIVEL       automovel           grave
# 13794191                COLISAO       automovel           grave
# 13794203         NAO DISPONIVEL       automovel           grave
# 13794204          ATROPELAMENTO       automovel           grave
#
#            tipo_sinistro
# 8          atropelamento
# 12         atropelamento
# 17         atropelamento
# 20         atropelamento
# 21         atropelamento
# ...                  ...
# 13794016  nao_disponivel
# 13794189  nao_disponivel
# 13794191  nao_disponivel
# 13794203  nao_disponivel
# 13794204  nao_disponivel
#
# [1772552 rows x 22 columns]

# %%
df_sinistros.tipo_de_veiculo.value_counts()
# Out:
# tipo_de_veiculo
# automovel         736317
# motocicleta       678007
# nao_disponivel    170895
# caminhao           60254
# onibus             45917
# outros             43771
# bicicleta          37391
# Name: count, dtype: int64

# %%
df_sinistros['tipo_de_veiculo'] = df_sinistros.tipo_de_veiculo.replace({
    'automovel': 'Automóvel',
    'motocicleta': 'Motocicleta',
    'nao_disponivel': None,
    'caminhao': 'Caminhão',
    'onibus': 'Ônibus',
    'outros': 'Outros',
    'bicicleta': 'Bicicleta'
})

# %%
df_sinistros['tipo_sinistro'].value_counts()
# Out:
# tipo_sinistro
# colisao_lateral        461461
# outros                 429412
# colisao_frontal        269489
# colisao_traseira       199617
# choque                  93723
# tombamento              89923
# atropelamento           77236
# colisao_transversal     60145
# nao_disponivel          56586
# capotamento             20980
# engavetamento           11145
# colisao_outros           2835
# Name: count, dtype: int64

# %%
df_sinistros['tipo_sinistro'] = df_sinistros['tipo_sinistro'].replace({
    'colisao_lateral': 'Colisão Lateral',
    'outros': 'Outros',
    'colisao_frontal': 'Colisão Frontal',
    'colisao_traseira': 'Colisão Traseira',
    'choque': 'Choque',
    'tombamento': 'Tombamento',
    'atropelamento': 'Atropelamento',
    'colisao_transversal': 'Colisão Transversal',
    'nao_disponivel': None,
    'capotamento': 'Capotamento',
    'engavetamento': 'Engavetamento',
    'colisao_outros': 'Outros'
})

# %%
df_sinistros['tipo_sinistro'].value_counts()
# Out:
# tipo_sinistro
# Colisão Lateral        461461
# Outros                 432247
# Colisão Frontal        269489
# Colisão Traseira       199617
# Choque                  93723
# Tombamento              89923
# Atropelamento           77236
# Colisão Transversal     60145
# Capotamento             20980
# Engavetamento           11145
# Name: count, dtype: int64

# %%
df_sinistros['gravidade'].value_counts()
# Out:
# gravidade
# nao_disponivel    822852
# leve              797722
# grave             103482
# fatal              48496
# Name: count, dtype: int64

# %%
df_sinistros['gravidade'] = df_sinistros['gravidade'].replace({
    'nao_disponivel': None,
    'leve': 'Leve',
    'grave': 'Grave',
    'fatal': 'Fatal'
})

# %%
df_sinistros
# Out:
#           id_sinistro       tipo_registro data_sinistro  ano_sinistro  \
# 8             1557410  SINISTRO NAO FATAL    2022-01-04          2022
# 12            2072299  SINISTRO NAO FATAL    2022-01-04          2022
# 17            1365234  SINISTRO NAO FATAL    2022-01-05          2022
# 20            1678076  SINISTRO NAO FATAL    2022-01-05          2022
# 21            1824438  SINISTRO NAO FATAL    2022-01-05          2022
# ...               ...                 ...           ...           ...
# 13794016      2605204  SINISTRO NAO FATAL    2025-05-20          2025
# 13794189      2604901  SINISTRO NAO FATAL    2025-05-28          2025
# 13794191      2607605  SINISTRO NAO FATAL    2025-05-28          2025
# 13794203      2607530  SINISTRO NAO FATAL    2025-05-29          2025
# 13794204      2606142  SINISTRO NAO FATAL    2025-05-29          2025
#
#           mes_sinistro  dia_sinistro ano_mes_sinistro hora_sinistro  \
# 8                    1             4          2022/01      20:09:00
# 12                   1             4          2022/01      12:15:00
# 17                   1             5          2022/01      17:10:00
# 20                   1             5          2022/01      22:28:00
# 21                   1             5          2022/01      06:52:00
# ...                ...           ...              ...           ...
# 13794016             5            20          2025/05      08:13:00
# 13794189             5            28          2025/05      07:32:00
# 13794191             5            28          2025/05      11:01:00
# 13794203             5            29          2025/05      07:10:00
# 13794204             5            29          2025/05      09:16:00
#
#                               logradouro  numero_logradouro         tipo_via  \
# 8                     PRAÇA DOS ANDRADAS                1.0  VIAS MUNICIPAIS
# 12                     ESTRADA DO ELENCO              915.0  VIAS MUNICIPAIS
# 17                    RUA JÚLIO MESQUITA              206.0  VIAS MUNICIPAIS
# 20              ACESSO MANOEL DA NÓBREGA                1.0  VIAS MUNICIPAIS
# 21                                SP 055              324.0         RODOVIAS
# ...                                  ...                ...              ...
# 13794016  RUA JOAQUINA ANGELICA FERREIRA              265.0  VIAS MUNICIPAIS
# 13794189         AVENIDA PASCHOAL THOMEU              100.0  VIAS MUNICIPAIS
# 13794191                      RUA BRASIL             1401.0  VIAS MUNICIPAIS
# 13794203                     RUA ANGICAL                1.0  VIAS MUNICIPAIS
# 13794204            AVENIDA CAPITAO JOAO              100.0  VIAS MUNICIPAIS
#
#            latitude  longitude            municipio  \
# 8        -23.936463 -46.332609               SANTOS
# 12       -23.411059 -46.485206            GUARULHOS
# 17       -23.522161 -47.474900             SOROCABA
# 20       -23.993034 -46.495588          SAO VICENTE
# 21       -24.151463 -46.732772             ITANHAEM
# ...             ...        ...                  ...
# 13794016 -20.045300 -47.747840            IGARAPAVA
# 13794189 -23.423120 -46.407210            GUARULHOS
# 13794191 -23.209896 -46.873071              JUNDIAI
# 13794203 -23.254958 -45.909890  SAO JOSE DOS CAMPOS
# 13794204 -23.668581 -46.462012                 MAUA
#
#                regiao_administrativa administracao   conservacao jurisdicao  \
# 8                   Baixada Santista    PREFEITURA    PREFEITURA  MUNICIPAL
# 12        Metropolitana de São Paulo    PREFEITURA    PREFEITURA  MUNICIPAL
# 17                          Sorocaba    PREFEITURA    PREFEITURA  MUNICIPAL
# 20                  Baixada Santista    PREFEITURA    PREFEITURA  MUNICIPAL
# 21                  Baixada Santista        ARTESP  NOVO LITORAL   ESTADUAL
# ...                              ...           ...           ...        ...
# 13794016                      Franca    PREFEITURA    PREFEITURA  MUNICIPAL
# 13794189  Metropolitana de São Paulo    PREFEITURA    PREFEITURA  MUNICIPAL
# 13794191                    Campinas    PREFEITURA    PREFEITURA  MUNICIPAL
# 13794203         São José dos Campos    PREFEITURA    PREFEITURA  MUNICIPAL
# 13794204  Metropolitana de São Paulo    PREFEITURA    PREFEITURA  MUNICIPAL
#
#          tipo_acidente_primario tipo_de_veiculo gravidade  tipo_sinistro
# 8                 ATROPELAMENTO       Bicicleta      None  Atropelamento
# 12                ATROPELAMENTO       Bicicleta      None  Atropelamento
# 17                ATROPELAMENTO       Bicicleta      None  Atropelamento
# 20                ATROPELAMENTO       Bicicleta      None  Atropelamento
# 21                ATROPELAMENTO       Bicicleta      None  Atropelamento
# ...                         ...             ...       ...            ...
# 13794016         NAO DISPONIVEL       Automóvel     Grave           None
# 13794189         NAO DISPONIVEL       Automóvel     Grave           None
# 13794191                COLISAO       Automóvel     Grave           None
# 13794203         NAO DISPONIVEL       Automóvel     Grave           None
# 13794204          ATROPELAMENTO       Automóvel     Grave           None
#
# [1772552 rows x 22 columns]

# %%
df_sinistros.logradouro = df_sinistros.logradouro.str.title()

# %%
df_sinistros.municipio = df_sinistros.municipio.str.title()

# %%
df_sinistros.tipo_via = df_sinistros.tipo_via.str.title()

# %%
df_sinistros.tipo_registro = df_sinistros.tipo_registro.str.title()

# %%
df_sinistros.tipo_registro.value_counts()
# Out:
# tipo_registro
# Sinistro Nao Fatal    1713021
# Sinistro Fatal          59531
# Name: count, dtype: int64

# %%
df_sinistros.tipo_registro = df_sinistros.tipo_registro.replace({
    'Sinistro Nao Fatal': 'Sinistro Não Fatal'
})

# %%
df_sinistros.administracao.value_counts()
# Out:
# administracao
# PREFEITURA               1496252
# CONCESSIONÁRIA            115248
# DER                       106322
# NAO DISPONIVEL             48241
# ARTESP                      2995
# DNIT                        2667
# CONCESSIONÁRIA-ARTESP         75
# CONCESSIONÁRIA-ANTT            2
# Name: count, dtype: int64

# %%
df_sinistros.administracao = df_sinistros.administracao.str.title()

# %%
df_sinistros.administracao = df_sinistros.administracao.replace({
    'Der': 'DER',
    'Artesp': 'ARTESP',
    'Dnit': 'DNIT',
    'Concessionária-Antt': 'Concessionária-ANTT',
    'Concessionária-Artesp': 'Concessionária-ARTESP',
    'Nao Disponivel': None
})

# %%
df_sinistros.conservacao.value_counts()
# Out:
# conservacao
# PREFEITURA                    1496842
# NAO DISPONIVEL                  59462
# AUTOBAN                         15217
# NOVADUTRA                       10655
# 10.02                           10021
#                                ...
# DR12 - PRESIDENTE PRUDENTE         10
# DR05 - CUBATÃO                      4
# DR11 - ARAÇATUBA                    4
# DR04 - ARARAQUARA                   2
# DR07 - ASSIS                        1
# Name: count, Length: 98, dtype: int64

# %%
df_sinistros.conservacao = df_sinistros.conservacao.str.title()

# %%
df_sinistros['tipo_sinistro'].value_counts()
# Out:
# tipo_sinistro
# Colisão Lateral        461461
# Outros                 432247
# Colisão Frontal        269489
# Colisão Traseira       199617
# Choque                  93723
# Tombamento              89923
# Atropelamento           77236
# Colisão Transversal     60145
# Capotamento             20980
# Engavetamento           11145
# Name: count, dtype: int64

# %%
df_sinistros['tipo_sinistro'] = df_sinistros['tipo_sinistro'].fillna(df_sinistros['tipo_acidente_primario'])
df_sinistros['tipo_sinistro'] = df_sinistros['tipo_sinistro'].str.title()
df_sinistros['tipo_sinistro'] = df_sinistros['tipo_sinistro'].replace({"Colisao": "Colisão", "Nao Disponivel": None})

# %%
df_sinistros.jurisdicao = df_sinistros.jurisdicao.str.title()

# %%
df_sinistros = df_sinistros.drop(columns={
    'mes_sinistro',
    'dia_sinistro',
    'ano_mes_sinistro',
    'ano_sinistro',
    'tipo_acidente_primario'
})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 df_sinistros = df_sinistros.drop(columns={
#       2     'mes_sinistro',
#       3     'dia_sinistro',
#       4     'ano_mes_sinistro',
#       5     'ano_sinistro',
#       6     'tipo_acidente_primario'
#       7 })
#
# File c:\Users\Matheus\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
#    5595         errors=errors,
#    5596     )
#
# File c:\Users\Matheus\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4807, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4805 for axis, labels in axes.items():
#    4806     if labels is not None:
# -> 4807         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4809 if inplace:
#    4810     self._update_inplace(obj)
#
# File c:\Users\Matheus\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4849, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4847         new_axis = axis.drop(labels, level=level, errors=errors)
#    4848     else:
# -> 4849         new_axis = axis.drop(labels, errors=errors)
#    4850     indexer = axis.get_indexer(new_axis)
#    4852 # Case for non-unique axis
#    4853 else:
#
# File c:\Users\Matheus\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:7098, in Index.drop(self, labels, errors)
#    7096 if mask.any():
#    7097     if errors != "ignore":
# -> 7098         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7099     indexer = indexer[~mask]
#    7100 return self.delete(indexer)
#
# KeyError: "['dia_sinistro', 'ano_sinistro', 'mes_sinistro', 'ano_mes_sinistro'] not found in axis"

# %%
df_sinistros
# Out:
#           id_sinistro       tipo_registro data_sinistro hora_sinistro  \
# 8             1557410  Sinistro Não Fatal    2022-01-04      20:09:00
# 12            2072299  Sinistro Não Fatal    2022-01-04      12:15:00
# 17            1365234  Sinistro Não Fatal    2022-01-05      17:10:00
# 20            1678076  Sinistro Não Fatal    2022-01-05      22:28:00
# 21            1824438  Sinistro Não Fatal    2022-01-05      06:52:00
# ...               ...                 ...           ...           ...
# 13794016      2605204  Sinistro Não Fatal    2025-05-20      08:13:00
# 13794189      2604901  Sinistro Não Fatal    2025-05-28      07:32:00
# 13794191      2607605  Sinistro Não Fatal    2025-05-28      11:01:00
# 13794203      2607530  Sinistro Não Fatal    2025-05-29      07:10:00
# 13794204      2606142  Sinistro Não Fatal    2025-05-29      09:16:00
#
#                               logradouro  numero_logradouro         tipo_via  \
# 8                     Praça Dos Andradas                1.0  Vias Municipais
# 12                     Estrada Do Elenco              915.0  Vias Municipais
# 17                    Rua Júlio Mesquita              206.0  Vias Municipais
# 20              Acesso Manoel Da Nóbrega                1.0  Vias Municipais
# 21                                Sp 055              324.0         Rodovias
# ...                                  ...                ...              ...
# 13794016  Rua Joaquina Angelica Ferreira              265.0  Vias Municipais
# 13794189         Avenida Paschoal Thomeu              100.0  Vias Municipais
# 13794191                      Rua Brasil             1401.0  Vias Municipais
# 13794203                     Rua Angical                1.0  Vias Municipais
# 13794204            Avenida Capitao Joao              100.0  Vias Municipais
#
#            latitude  longitude            municipio  \
# 8        -23.936463 -46.332609               Santos
# 12       -23.411059 -46.485206            Guarulhos
# 17       -23.522161 -47.474900             Sorocaba
# 20       -23.993034 -46.495588          Sao Vicente
# 21       -24.151463 -46.732772             Itanhaem
# ...             ...        ...                  ...
# 13794016 -20.045300 -47.747840            Igarapava
# 13794189 -23.423120 -46.407210            Guarulhos
# 13794191 -23.209896 -46.873071              Jundiai
# 13794203 -23.254958 -45.909890  Sao Jose Dos Campos
# 13794204 -23.668581 -46.462012                 Maua
#
#                regiao_administrativa administracao   conservacao jurisdicao  \
# 8                   Baixada Santista    Prefeitura    Prefeitura  Municipal
# 12        Metropolitana de São Paulo    Prefeitura    Prefeitura  Municipal
# 17                          Sorocaba    Prefeitura    Prefeitura  Municipal
# 20                  Baixada Santista    Prefeitura    Prefeitura  Municipal
# 21                  Baixada Santista        ARTESP  Novo Litoral   Estadual
# ...                              ...           ...           ...        ...
# 13794016                      Franca    Prefeitura    Prefeitura  Municipal
# 13794189  Metropolitana de São Paulo    Prefeitura    Prefeitura  Municipal
# 13794191                    Campinas    Prefeitura    Prefeitura  Municipal
# 13794203         São José dos Campos    Prefeitura    Prefeitura  Municipal
# 13794204  Metropolitana de São Paulo    Prefeitura    Prefeitura  Municipal
#
#          tipo_acidente_primario tipo_de_veiculo gravidade  tipo_sinistro
# 8                 ATROPELAMENTO       Bicicleta      None  Atropelamento
# 12                ATROPELAMENTO       Bicicleta      None  Atropelamento
# 17                ATROPELAMENTO       Bicicleta      None  Atropelamento
# 20                ATROPELAMENTO       Bicicleta      None  Atropelamento
# 21                ATROPELAMENTO       Bicicleta      None  Atropelamento
# ...                         ...             ...       ...            ...
# 13794016         NAO DISPONIVEL       Automóvel     Grave           None
# 13794189         NAO DISPONIVEL       Automóvel     Grave           None
# 13794191                COLISAO       Automóvel     Grave        Colisão
# 13794203         NAO DISPONIVEL       Automóvel     Grave           None
# 13794204          ATROPELAMENTO       Automóvel     Grave  Atropelamento
#
# [1772552 rows x 18 columns]

# %%
metade = len(df_sinistros) // 2
df1 = df_sinistros.iloc[:metade]     # primeira metade
df2 = df_sinistros.iloc[metade:]     # segunda metade

# Salvando como Excel
df1.to_excel("sinistros1.xlsx", index=False)
df2.to_excel("sinistros2.xlsx", index=False)
